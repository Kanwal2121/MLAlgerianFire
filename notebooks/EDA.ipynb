# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_frame=pd.read_csv('Algerian_forest_fires_dataset.csv')

# %%
data_frame
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7   3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4   4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1   2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6   1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8   3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...   ...   ...  ...
# 239   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 240   27      9  2012           28   87   15    4.4  41.1   6.5     8  0.1
# 241   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 242   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 243   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI     Classes
# 0     3.4  0.5   not fire
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4    RH          244 non-null    int64
#  5    Ws          244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
# dtypes: float64(5), int64(6), object(3)
# memory usage: 26.8+ KB

# %%
mode=data_frame["Classes  "].mode()

# %%
data_frame
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7   3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4   4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1   2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6   1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8   3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...   ...   ...  ...
# 239   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 240   27      9  2012           28   87   15    4.4  41.1   6.5     8  0.1
# 241   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 242   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 243   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI     Classes
# 0     3.4  0.5   not fire
# ...

# %%
mode[0]
# Out:
# 'fire   '

# %%
data_frame['Classes  ']=data_frame['Classes  '].fillna(mode[0])

# %%
data_frame.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
data_frame['FWI']=data_frame['FWI'].replace('fire   ',np.nan)

# %%
data_frame.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC   DC  ISI  BUI  \
# 122    1      6  2012           32   71   12    0.7  57.1  2.5  8.2  0.6  2.8
#
#      FWI    Classes
# 122  0.2  not fire

# %%
data_frame.columns=data_frame.columns.str.strip()

# %%
data_frame['FWI'].unique()
# Out:
# array(['0.5', '0.4', '0.1', '0', '2.5', '7.2', '7.1', '0.3', '0.9', '5.6',
#        '0.2', '1.4', '2.2', '2.3', '3.8', '7.5', '8.4', '10.6', '15',
#        '13.9', '3.9', '12.9', '1.7', '4.9', '6.8', '3.2', '8', '0.6',
#        '3.4', '0.8', '3.6', '6', '10.9', '4', '8.8', '2.8', '2.1', '1.3',
#        '7.3', '15.3', '11.3', '11.9', '10.7', '15.7', '6.1', '2.6', '9.9',
#        '11.6', '12.1', '4.2', '10.2', '6.3', '14.6', '16.1', '17.2',
#        '16.8', '18.4', '20.4', '22.3', '20.9', '20.3', '13.7', '13.2',
#        '19.9', '30.2', '5.9', '7.7', '9.7', '8.3', '0.7', '4.1', '1',
#        '3.1', '1.9', '10', '16.7', '1.2', '5.3', '6.7', '9.5', '12',
#        '6.4', '5.2', '3', '9.6', '4.7', nan, '14.1', '9.1', '13', '17.3',
#        '30', '25.4', '16.3', '9', '14.5', '13.5', '19.5', '12.6', '12.7',
#        '21.6', '18.8', '10.5', '5.5', '14.8', '24', '26.3', '12.2',
#        '18.1', '24.5', '26.9', '31.1', '30.3', '26.1', '16', '19.4',
# ...

# %%
data_frame['DC'].unique()
# Out:
# array(['7.6', '7.1', '6.9', '14.2', '22.2', '30.5', '38.3', '38.8',
#        '46.3', '54.3', '61.4', '17', '7.8', '7.4', '8', '16', '27.1',
#        '31.6', '39.5', '47.7', '55.8', '63.8', '71.8', '80.3', '88.5',
#        '84.4', '92.8', '8.6', '8.3', '9.2', '18.5', '27.9', '37', '40.4',
#        '49.8', '9.3', '18.7', '27.7', '37.2', '22.9', '25.5', '34.1',
#        '43.1', '52.8', '62.1', '71.5', '79.9', '71.3', '79.7', '88.7',
#        '98.6', '108.5', '117.8', '127', '136', '145.7', '10.2', '10',
#        '19.8', '29.7', '39.1', '48.6', '47', '57', '67', '77', '75.1',
#        '85.1', '94.7', '92.5', '90.4', '100.7', '110.9', '120.9', '130.6',
#        '141.1', '151.3', '161.5', '171.3', '181.3', '190.6', '200.2',
#        '210.4', '220.4', '180.4', '8.7', '7.5', '7', '15.7', '24', '32.2',
#        '30.1', '8.4', '8.9', '16.6', '7.3', '24.3', '33.1', '41.3',
#        '49.3', '57.9', '41.4', '30.4', '15.2', '7.7', '16.3', '24.9',
# ...

# %%
data_frame[~data_frame['DC'].str.isnumeric()]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   25      9  2012           28  70  15   0.0  79.9  13.8  36.1  2.4  14.1
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          243 non-null    object
#  13  Classes      244 non-null    object
# dtypes: float64(5), int64(6), object(3)
# memory usage: 26.8+ KB

# %%
data_frame['FWI']=data_frame['FWI'].fillna(data_frame['FWI'].mean())

# %%
data_frame['FWI']=data_frame['FWI'].astype(float)

# %%
objects = [i  for i in data_frame.columns if data_frame[i].dtypes =='O']

# %%
objects
# Out:
# ['DC', 'FWI', 'Classes']

# %%
for i in objects:
    if i!='Classes':
        data_frame[i].astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 for i in objects:
#       2     if i!='Classes':
#       3         data_frame[i].astype(float)
#
# NameError: name 'objects' is not defined

# %%
data_frame["DC"]=data_frame["DC"].replace('14.6 9',np.nan)

# %%
data_frame["DC"]=data_frame["DC"].astype(float)

# %%
data_frame["DC"]=data_frame["DC"].fillna(data_frame["DC"].mean())

# %%
data_frame.loc['14.6 9']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 data_frame.loc['14.6 9']
#
# File ~/Desktop/Code/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Desktop/Code/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/Desktop/Code/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      244 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 26.8+ KB

# %%
data_frame.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
data_frame.loc[:122,"Region"]=0
data_frame.loc[122:,"Region"]=1

# %%
data_frame
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# ...

# %%
data_frame['Region']=data_frame['Region'].astype(int)

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      244 non-null    object
#  14  Region       244 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.7+ KB

# %%
data_frame.to_csv('cleaneddataset.csv',index=False)

# %%
df=data_frame.copy()

# %%
df.drop(['day','month','year'],axis=1,inplace=True)

# %%
df
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5  notfire
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4  notfire
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1  notfire
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0  notfire
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5  notfire
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 239           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5     fire
# 240           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0  notfire
# 241           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2  notfire
# 242           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7  notfire
# 243           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5  notfire
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
#encoding
df['Classes']=np.where(df['Classes'] == 'notfire',0,1)

# %%
df['Classes']=df['Classes'].str.replace(' ','')

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    138
# 0    106
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.654443 -0.278132 -0.326786  0.677491  0.483105
# RH             -0.654443  1.000000  0.236084  0.222968 -0.645658 -0.405133
# Ws             -0.278132  0.236084  1.000000  0.170169 -0.163255 -0.001246
# Rain           -0.326786  0.222968  0.170169  1.000000 -0.544045 -0.288548
# FFMC            0.677491 -0.645658 -0.163255 -0.544045  1.000000  0.602391
# DMC             0.483105 -0.405133 -0.001246 -0.288548  0.602391  1.000000
# DC              0.374909 -0.225621  0.079005 -0.297975  0.506778  0.875887
# ISI             0.607551 -0.690637  0.015248 -0.347105  0.739730  0.674499
# BUI             0.455504 -0.348587  0.029756 -0.299171  0.589652  0.982073
# FWI             0.564599 -0.577577  0.032315 -0.324369  0.690289  0.875827
# Classes         0.518119 -0.435023 -0.066529 -0.379449  0.770114  0.584188
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.boxplot(df["FWI"])
# Out:
# <Axes: ylabel='FWI'>

# %%
df
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 239           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 240           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 241           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 242           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 243           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    138
# 0    106
# Name: count, dtype: int64

# %%
X=df.drop('FWI',axis=1)

# %%
y=df['FWI']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
#feature selection

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.664492 -0.249312 -0.375047  0.703238  0.485379
# RH             -0.664492  1.000000  0.235766  0.262550 -0.637201 -0.398168
# Ws             -0.249312  0.235766  1.000000  0.262759 -0.169489 -0.013533
# Rain           -0.375047  0.262550  0.262759  1.000000 -0.585018 -0.291338
# FFMC            0.703238 -0.637201 -0.169489 -0.585018  1.000000  0.602278
# DMC             0.485379 -0.398168 -0.013533 -0.291338  0.602278  1.000000
# DC              0.380467 -0.222255  0.077630 -0.297674  0.512196  0.877730
# ISI             0.609525 -0.694976  0.015384 -0.353219  0.744270  0.652894
# BUI             0.458575 -0.344365  0.022529 -0.301347  0.592841  0.981876
# Classes         0.512818 -0.429397 -0.078171 -0.394262  0.774398  0.580530
# Region          0.256099 -0.397053 -0.229797 -0.096985  0.237434  0.197489
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
plt.Figure(figsize=(15,15))
corr=X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()

    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                col = corr_matrix.columns[i]
                col_corr.add(col)

    return col_corr

# %%
corr_f=correlation(X_train,0.85)

# %%
X_train.drop(corr_f,axis=1,inplace=True)

# %%
X_test.drop(corr_f,axis=1,inplace=True)

# %%
X_train
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC  ISI  Classes  Region
# 115           29  65  19   0.6  68.3   5.5  1.5        0       0
# 181           36  56  16   0.0  88.9  23.8  8.2        1       1
# 225           31  72  14   0.0  84.2   8.3  3.8        1       1
# 68            32  60  18   0.3  77.1  11.3  2.2        0       0
# 104           25  86  21   4.6  40.9   1.3  0.1        0       0
# ..           ...  ..  ..   ...   ...   ...  ...      ...     ...
# 106           24  82  15   0.4  44.9   0.9  0.2        0       0
# 14            28  80  17   3.1  49.4   3.0  0.4        0       0
# 92            25  76  17   7.2  46.0   1.3  0.2        0       0
# 179           33  57  16   0.0  87.5  15.7  6.7        1       1
# 102           30  77  21   1.8  58.5   1.9  1.1        0       0
#
# [183 rows x 9 columns]

# %% [markdown]
# standard

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train
# Out:
# array([[-0.81085018,  0.16311382,  1.29231566, ..., -0.773495  ,
#         -1.1098231 , -1.00547949],
#        [ 1.06405791, -0.44884168,  0.15167049, ...,  0.83939993,
#          0.9010445 ,  0.99455037],
#        [-0.27516216,  0.63907922, -0.60875963, ..., -0.21981465,
#          0.9010445 ,  0.99455037],
#        ...,
#        [-1.88222624,  0.91105944,  0.53188555, ..., -1.08644476,
#         -1.1098231 , -1.00547949],
#        [ 0.26052587, -0.38084663,  0.15167049, ...,  0.47830405,
#          0.9010445 ,  0.99455037],
#        [-0.54300617,  0.9790545 ,  2.05274578, ..., -0.86978723,
#         -1.1098231 , -1.00547949]], shape=(183, 9))

# %%
plt.boxplot(X_train)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16d75b9a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16d75be80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16d75b5e0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x16d7404c0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x16d7407c0>,
# ...
#  'means': []}

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
y_predict=lr.predict(X_test)

# %%
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error,r2_score

# %%
from sklearn.metrics import mean_absolute_error,r2_score
mae=mean_absolute_error(y_test,y_predict)
score=r2_score(y_test,y_predict)

# %%
mae,score
# Out:
# (0.6075669665526342, 0.9888523587097926)

# %%
plt.scatter(y_test,y_predict)

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()
lasso.fit(X_train,y_train)
y_pred=lasso.predict(X_test)
plt.scatter(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)

score
# Out:
# 0.9498780896144685

# %%
mae
# Out:
# 1.2227720614689963

# %%
from sklearn.linear_model import Ridge
rig=Ridge()
rig.fit(X_train,y_train)
y_pred1=rig.predict(X_test)
plt.scatter(y_test,y_pred1)
mae1=mean_absolute_error(y_test,y_pred1)
score1=r2_score(y_test,y_pred1)
# Out:
# /Users/kanwal/Desktop/Code/venv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/kanwal/Desktop/Code/venv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/kanwal/Desktop/Code/venv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
score1,mae1
# Out:
# (0.9881590396929899, 0.6309880485441139)

# %%
from sklearn.linear_model import ElasticNet
el=ElasticNet()
el.fit(X_train,y_train)
y_prd=el.predict(X_test)
plt.scatter(y_test,y_prd)
mae1=mean_absolute_error(y_test,y_prd)
score1=r2_score(y_test,y_prd)

# %%
mae1,score1
# Out:
# (1.9197940304923347, 0.874882424178001)

# %%
from sklearn.linear_model import LassoCV
lassocv=LassoCV(cv=5)
lassocv.fit(X_train,y_train)
# Out:
# LassoCV(cv=5)
